# %% [markdown]
# <a href="https://colab.research.google.com/github/Annu1782003/task4/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ejlok1/toronto-emotional-speech-set-tess
# Out:
# Downloading toronto-emotional-speech-set-tess.zip to /content
# 100% 426M/428M [00:11<00:00, 42.6MB/s]
# 100% 428M/428M [00:11<00:00, 39.1MB/s]

# %%
from zipfile import ZipFile
dataset = '/content/toronto-emotional-speech-set-tess.zip'
with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk('/content/tess toronto emotional speech set data'):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_neutral/OAF_lose_neutral.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_neutral/OAF_puff_neutral.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_neutral/OAF_met_neutral.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_neutral/OAF_merge_neutral.wav',
#  '/content/tess toronto emotional speech set data/TESS Toronto emotional speech set data/OAF_neutral/OAF_should_neutral.wav']

# %%
labels[:5]
# Out:
# ['neutral', 'neutral', 'neutral', 'neutral', 'neutral']

# %%
## Create a dataframe
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                                               speech    label
# 0  /content/tess toronto emotional speech set dat...  neutral
# 1  /content/tess toronto emotional speech set dat...  neutral
# 2  /content/tess toronto emotional speech set dat...  neutral
# 3  /content/tess toronto emotional speech set dat...  neutral
# 4  /content/tess toronto emotional speech set dat...  neutral

# %%
df['label'].value_counts()
# Out:
# label
# neutral    400
# sad        400
# happy      400
# angry      400
# fear       400
# disgust    400
# ps         400
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10,4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

def spectogram(data, sr, emotion):
    x = librosa.stft(data)
    xdb = librosa.amplitude_to_db(abs(x))
    plt.figure(figsize=(11,4))
    plt.title(emotion, size=20)
    librosa.display.specshow(xdb, sr=sr, x_axis='time', y_axis='hz')
    plt.colorbar()

# %%
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'angry'
path = np.array(df['speech'][df['label']==emotion])[1]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'disgust'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'neutral'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'sad'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'ps'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
emotion = 'happy'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)
waveplot(data, sampling_rate, emotion)
spectogram(data, sampling_rate, emotion)
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Feature Extraction

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-5.5406396e+02,  9.2979568e+01,  3.3090492e+01,  9.8928089e+00,
#         1.1133100e+01,  2.2158064e+01,  2.0170021e+00, -1.1826174e+01,
#        -1.5838679e+01, -8.1426229e+00, -1.2399307e+01, -7.0432490e-01,
#        -7.8697739e+00, -6.0489488e-01,  9.5117769e+00, -2.8726063e+00,
#        -7.1191722e-01,  7.4903407e+00, -2.5559416e+00,  1.4069926e+00,
#         1.4483671e+00,  4.4465807e-01, -1.6433730e+00, -1.6639371e+00,
#        -7.7541480e+00, -7.4216050e-01, -1.1189000e+01, -5.0231940e-01,
#        -2.5262144e+00, -1.0285549e+00, -7.3935142e+00, -6.9425611e+00,
#        -1.0828019e+01, -3.8752334e+00,  4.1653366e+00,  1.8633396e+01,
#         3.1395660e+01,  4.1924854e+01,  3.3784626e+01,  3.0189295e+01],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-554.06396, 92.97957, 33.090492, 9.892809, 11...
# 1       [-523.381, 87.58419, 19.183575, -4.133721, 6.9...
# 2       [-519.0371, 107.21107, 21.98441, -2.4445925, 1...
# 3       [-528.38416, 109.01874, 22.413408, -7.829714, ...
# 4       [-505.9471, 71.733154, 15.318556, 15.384199, 1...
#                               ...
# 2795    [-395.3472, 85.8411, -11.019002, 22.33104, -5....
# 2796    [-428.04822, 57.957573, 1.2415637, 37.944313, ...
# 2797    [-379.5944, 74.28096, -20.734558, 27.009659, 4...
# 2798    [-415.5673, 86.70689, -12.849749, 21.769737, -...
# 2799    [-410.98706, 70.45046, -16.830345, 23.867819, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
## input split
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# Create the LSTM model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 256)               264192
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 10s 185ms/step - loss: 1.2653 - accuracy: 0.4906 - val_loss: 1.8425 - val_accuracy: 0.3125
# Epoch 2/50
# 35/35 [==============================] - 7s 194ms/step - loss: 0.4697 - accuracy: 0.8335 - val_loss: 1.3261 - val_accuracy: 0.6429
# Epoch 3/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.2257 - accuracy: 0.9272 - val_loss: 2.0769 - val_accuracy: 0.5429
# Epoch 4/50
# 35/35 [==============================] - 7s 194ms/step - loss: 0.1619 - accuracy: 0.9491 - val_loss: 2.3087 - val_accuracy: 0.5768
# Epoch 5/50
# 35/35 [==============================] - 6s 160ms/step - loss: 0.1697 - accuracy: 0.9536 - val_loss: 2.0274 - val_accuracy: 0.5875
# Epoch 6/50
# 35/35 [==============================] - 7s 197ms/step - loss: 0.1579 - accuracy: 0.9500 - val_loss: 1.4817 - val_accuracy: 0.6946
# Epoch 7/50
# 35/35 [==============================] - 6s 167ms/step - loss: 0.1197 - accuracy: 0.9674 - val_loss: 2.4782 - val_accuracy: 0.5375
# Epoch 8/50
# 35/35 [==============================] - 7s 210ms/step - loss: 0.0800 - accuracy: 0.9777 - val_loss: 1.5373 - val_accuracy: 0.6857
# Epoch 9/50
# 35/35 [==============================] - 6s 164ms/step - loss: 0.0612 - accuracy: 0.9826 - val_loss: 1.8736 - val_accuracy: 0.6821
# Epoch 10/50
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0816 - accuracy: 0.9790 - val_loss: 1.4933 - val_accuracy: 0.6946
# Epoch 11/50
# 35/35 [==============================] - 6s 166ms/step - loss: 0.0643 - accuracy: 0.9808 - val_loss: 1.3617 - val_accuracy: 0.7196
# Epoch 12/50
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 1.5242 - val_accuracy: 0.7071
# Epoch 13/50
# 35/35 [==============================] - 6s 185ms/step - loss: 0.0434 - accuracy: 0.9862 - val_loss: 1.5774 - val_accuracy: 0.6946
# Epoch 14/50
# 35/35 [==============================] - 11s 303ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 1.2437 - val_accuracy: 0.7625
# Epoch 15/50
# 35/35 [==============================] - 9s 263ms/step - loss: 0.0273 - accuracy: 0.9924 - val_loss: 1.1718 - val_accuracy: 0.7429
# Epoch 16/50
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0714 - accuracy: 0.9772 - val_loss: 1.6481 - val_accuracy: 0.6714
# Epoch 17/50
# 35/35 [==============================] - 7s 194ms/step - loss: 0.0843 - accuracy: 0.9746 - val_loss: 1.8994 - val_accuracy: 0.6196
# Epoch 18/50
# 35/35 [==============================] - 6s 163ms/step - loss: 0.0492 - accuracy: 0.9857 - val_loss: 1.9037 - val_accuracy: 0.6768
# Epoch 19/50
# 35/35 [==============================] - 9s 270ms/step - loss: 0.0360 - accuracy: 0.9888 - val_loss: 2.1381 - val_accuracy: 0.6732
# Epoch 20/50
# 35/35 [==============================] - 6s 163ms/step - loss: 0.0289 - accuracy: 0.9893 - val_loss: 2.3357 - val_accuracy: 0.6536
# Epoch 21/50
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0441 - accuracy: 0.9875 - val_loss: 1.6631 - val_accuracy: 0.7000
# Epoch 22/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0307 - accuracy: 0.9888 - val_loss: 1.7612 - val_accuracy: 0.7304
# Epoch 23/50
# 35/35 [==============================] - 9s 259ms/step - loss: 0.0690 - accuracy: 0.9772 - val_loss: 1.7353 - val_accuracy: 0.6732
# Epoch 24/50
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0399 - accuracy: 0.9879 - val_loss: 2.1526 - val_accuracy: 0.6518
# Epoch 25/50
# 35/35 [==============================] - 6s 182ms/step - loss: 0.0479 - accuracy: 0.9866 - val_loss: 2.0404 - val_accuracy: 0.6946
# Epoch 26/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0225 - accuracy: 0.9955 - val_loss: 1.7969 - val_accuracy: 0.7107
# Epoch 27/50
# 35/35 [==============================] - 7s 192ms/step - loss: 0.0190 - accuracy: 0.9933 - val_loss: 1.6566 - val_accuracy: 0.7107
# Epoch 28/50
# 35/35 [==============================] - 6s 167ms/step - loss: 0.0515 - accuracy: 0.9857 - val_loss: 1.1797 - val_accuracy: 0.7732
# Epoch 29/50
# 35/35 [==============================] - 7s 192ms/step - loss: 0.0295 - accuracy: 0.9933 - val_loss: 1.7036 - val_accuracy: 0.7250
# Epoch 30/50
# 35/35 [==============================] - 6s 181ms/step - loss: 0.0149 - accuracy: 0.9946 - val_loss: 1.3012 - val_accuracy: 0.7696
# Epoch 31/50
# 35/35 [==============================] - 7s 186ms/step - loss: 0.0129 - accuracy: 0.9964 - val_loss: 1.4964 - val_accuracy: 0.7589
# Epoch 32/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0531 - accuracy: 0.9821 - val_loss: 2.4508 - val_accuracy: 0.6286
# Epoch 33/50
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0528 - accuracy: 0.9862 - val_loss: 2.3334 - val_accuracy: 0.6446
# Epoch 34/50
# 35/35 [==============================] - 6s 167ms/step - loss: 0.0301 - accuracy: 0.9933 - val_loss: 1.0975 - val_accuracy: 0.8214
# Epoch 35/50
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0246 - accuracy: 0.9906 - val_loss: 1.7401 - val_accuracy: 0.7250
# Epoch 36/50
# 35/35 [==============================] - 6s 162ms/step - loss: 0.0177 - accuracy: 0.9946 - val_loss: 1.9246 - val_accuracy: 0.6732
# Epoch 37/50
# 35/35 [==============================] - 7s 198ms/step - loss: 0.0339 - accuracy: 0.9906 - val_loss: 1.4591 - val_accuracy: 0.7571
# Epoch 38/50
# 35/35 [==============================] - 6s 175ms/step - loss: 0.0172 - accuracy: 0.9955 - val_loss: 2.2170 - val_accuracy: 0.6536
# Epoch 39/50
# 35/35 [==============================] - 7s 196ms/step - loss: 0.0101 - accuracy: 0.9955 - val_loss: 1.4005 - val_accuracy: 0.7643
# Epoch 40/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0235 - accuracy: 0.9929 - val_loss: 1.7769 - val_accuracy: 0.6893
# Epoch 41/50
# 35/35 [==============================] - 7s 197ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 1.6531 - val_accuracy: 0.7036
# Epoch 42/50
# 35/35 [==============================] - 12s 329ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 1.2187 - val_accuracy: 0.7857
# Epoch 43/50
# 35/35 [==============================] - 6s 177ms/step - loss: 0.0205 - accuracy: 0.9951 - val_loss: 1.3024 - val_accuracy: 0.7821
# Epoch 44/50
# 35/35 [==============================] - 7s 188ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 1.3451 - val_accuracy: 0.7554
# Epoch 45/50
# 35/35 [==============================] - 6s 164ms/step - loss: 0.0517 - accuracy: 0.9866 - val_loss: 1.9342 - val_accuracy: 0.7196
# Epoch 46/50
# 35/35 [==============================] - 7s 195ms/step - loss: 0.0120 - accuracy: 0.9955 - val_loss: 1.6670 - val_accuracy: 0.7429
# Epoch 47/50
# 35/35 [==============================] - 6s 166ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.7951 - val_accuracy: 0.7411
# Epoch 48/50
# 35/35 [==============================] - 7s 203ms/step - loss: 0.0051 - accuracy: 0.9991 - val_loss: 1.7855 - val_accuracy: 0.7357
# Epoch 49/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0053 - accuracy: 0.9996 - val_loss: 1.6819 - val_accuracy: 0.7679
# Epoch 50/50
# 35/35 [==============================] - 7s 190ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 1.8933 - val_accuracy: 0.7357

# %% [markdown]
# Plot the results

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
